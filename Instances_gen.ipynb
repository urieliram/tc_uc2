perfil = [.71,.65,.62,.60,.58,.58,.60,.64,.73,.80,.82,.83,.82,.80,.79,.79,.83,.91,.90,.88,.85,.84,.79,.74]

# %%
## Aqui la configuración de las instancias.
instance=[]
instance.append((71 ,[(0,11),(1,18),(2,6),(3,3),(4,7),(5,8),(6,2),(7,5)]))
instance.append((72 ,[(0,11),(1,18),(2,6),(3,3),(4,7),(5,8),(6,2),(7,5)]))
instance.append((73,[(0,16),(1,17),(2,5),(3,3),(4,5),(5,6),(6,7),(7,3)]))
instance.append((74 ,[(0,13),(1,20),(2,4),(3,9),(4,4),(5,6),(6,2),(7,6)]))
instance.append((75 ,[(0,17),(1,16),(2,8),(3,8),(4,0),(5,6),(6,6),(7,5)]))
instance.append((76 ,[(0,14),(1,21),(2,9),(3,5),(4,8),(5,6),(6,3),(7,4)]))
instance.append((77 ,[(0,25),(1,18),(2,2),(3,4),(4,7),(5,5),(6,2),(7,8)]))
instance.append((78 ,[(0,16),(1,25),(2,5),(3,9),(4,3),(5,3),(6,8),(7,6)]))
instance.append((79 ,[(0,21),(1,21),(2,4),(3,3),(4,8),(5,10),(6,4),(7,5)]))
instance.append((80 ,[(0,17),(1,24),(2,8),(3,9),(4,8),(5,1),(6,8),(7,5)]))
instance.append((81 ,[(0,22),(1,21),(2,4),(3,9),(4,4),(5,3),(6,8),(7,10)]))
instance.append((82 ,[(0,19),(1,27),(2,6),(3,6),(4,8),(5,9),(6,3),(7,7)]))
instance.append((83 ,[(0,24),(1,23),(2,6),(3,7),(4,4),(5,8),(6,6),(7,8)]))
instance.append((84 ,[(0,24),(1,28),(2,6),(3,7),(4,6),(5,3),(6,12),(7,4)]))
instance.append((85 ,[(0,26),(1,24),(2,9),(3,4),(4,5),(5,10),(6,6),(7,7)]))
instance.append((86 ,[(0,22),(1,28),(2,4),(3,10),(4,5),(5,9),(6,7),(7,9)]))
instance.append((87 ,[(0,27),(1,26),(2,8),(3,14),(4,5),(5,6),(6,7),(7,4)]))
instance.append((88 ,[(0,24),(1,30),(2,4),(3,8),(4,10),(5,7),(6,10),(7,5)]))
instance.append((89 ,[(0,29),(1,28),(2,10),(3,6),(4,5),(5,9),(6,9),(7,6)]))
instance.append((90 ,[(0,25),(1,32),(2,9),(3,0),(4,10),(5,11),(6,9),(7,8)]))
instance.append((91 ,[(0,30),(1,29),(2,11),(3,9),(4,5),(5,2),(6,11),(7,9)]))
instance.append((92 ,[(0,32),(1,34),(2,9),(3,7),(4,8),(5,9),(6,4),(7,6)]))
instance.append((93 ,[(0,32),(1,36),(2,6),(3,4),(4,10),(5,7),(6,10),(7,6)]))
instance.append((94 ,[(0,29),(1,36),(2,11),(3,10),(4,6),(5,5),(6,7),(7,10)]))
instance.append((95 ,[(0,34),(1,32),(2,7),(3,5),(4,9),(5,9),(6,11),(7,9)]))
instance.append((96 ,[(0,32),(1,37),(2,9),(3,5),(4,7),(5,11),(6,9),(7,9)]))
instance.append((97 ,[(0,35),(1,34),(2,7),(3,11),(4,12),(5,4),(6,7),(7,11)]))
instance.append((98 ,[(0,32),(1,39),(2,5),(3,8),(4,5),(5,15),(6,13),(7,8)]))
instance.append((100 ,[(0,37),(1,36),(2,10),(3,12),(4,4),(5,12),(6,10),(7,5)]))
instance.append((101 ,[(0,33),(1,40),(2,9),(3,7),(4,7),(5,14),(6,5),(7,14)]))
instance.append((102 ,[(0,38),(1,37),(2,14),(3,10),(4,6),(5,7),(6,5),(7,14)]))
instance.append((103 ,[(0,35),(1,42),(2,8),(3,8),(4,8),(5,11),(6,14),(7,6)]))
instance.append((104 ,[(0,46),(1,45),(2,8),(3,0),(4,5),(5,0),(6,12),(7,16)]))
instance.append((105 ,[(0,37),(1,44),(2,8),(3,8),(4,9),(5,9),(6,13),(7,7)]))
instance.append((106 ,[(0,42),(1,40),(2,7),(3,11),(4,9),(5,10),(6,6),(7,13)]))
instance.append((107 ,[(0,38),(1,45),(2,8),(3,7),(4,10),(5,14),(6,10),(7,8)]))
instance.append((108 ,[(0,43),(1,42),(2,7),(3,12),(4,7),(5,15),(6,10),(7,7)]))
instance.append((109 ,[(0,40),(1,47),(2,9),(3,7),(4,15),(5,13),(6,7),(7,8)]))
instance.append((110 ,[(0,45),(1,44),(2,7),(3,16),(4,9),(5,10),(6,10),(7,7)]))
instance.append((111 ,[(0,41),(1,48),(2,9),(3,16),(4,11),(5,8),(6,9),(7,9)]))
instance.append((112 ,[(0,46),(1,45),(2,10),(3,15),(4,10),(5,3),(6,15),(7,10)]))
instance.append((113 ,[(0,43),(1,48),(2,16),(3,11),(4,9),(5,12),(6,9),(7,8)]))

# %%
nfile=71
for inst in instance:
    ngen = inst[0]
    lista = inst[1]
    ##Calculamos la demanda de cinco dias mas dos de fin de semana
    weekday    = []; weekend=[] ; weekend=[] ; demand=[] ; demand1=[] ; reserves=[]
    n_weekdays = 5
    n_weekend  = 2
    factor_we  = 0.8
    factor_re  = 0.05
    weekday    = perfil * n_weekdays
    capacidad  = 0
    ## Calculamos capacidad total de los generadores
    i = 0
    for item in datagen:
      print(item[3] , lista[i][1])
      capacidad = capacidad + item[3] * lista[i][1]
      i = i + 1

    for i in perfil:
        weekend.append(i * factor_we)
    weekend   = weekend * n_weekend
    demand1   = weekday + weekend

    for i in demand1:
        demand.append(i * capacidad)

    for i in demand:
        reserves.append(i * factor_re)

    print('capacidad',capacidad)
    result = {}
    tmp    = {}
    gen    = {}
    result["comments"     ] = 'x7-'+ str(ngen)+'G-UR-'+str(lista)
    result["time_periods" ] = len(demand)
    result["demand"       ] = demand
    result["reserves"     ] = reserves
    result["factor_demand"] = 1
    n = 1
    for item in lista:
      i = item[0]
      j = item[1]
      for k in range(j):
        startup1              = []
        piecewise_production1 = []
        for m in range(len(startup[i][0])):        
            startup1.append({"lag":startup[i][0][m],"cost":startup[i][1][m]})
        for m in range(len(piecewise[i][0])):
            piecewise_production1.append({"mw":piecewise[i][0][m],"cost":piecewise[i][1][m]})
        tmp["must_run"            ] = datagen[i][0]
        tmp["name"                ] = datagen[i][1] +"-"+ str(n)
        tmp["power_output_minimum"] = datagen[i][2]
        tmp["power_output_maximum"] = datagen[i][3]
        tmp["ramp_up_limit"       ] = datagen[i][4]
        tmp["ramp_down_limit"     ] = datagen[i][5]
        tmp["ramp_startup_limit"  ] = datagen[i][6]
        tmp["ramp_shutdown_limit" ] = datagen[i][7]
        tmp["time_up_minimum"     ] = datagen[i][8]
        tmp["time_down_minimum"   ] = datagen[i][9]
        tmp["power_output_t0"     ] = datagen[i][10]
        tmp["unit_on_t0"          ] = datagen[i][11]
        tmp["time_up_t0"          ] = datagen[i][12]
        tmp["time_down_t0"        ] = datagen[i][13]
        tmp["fixed_cost"          ] = datagen[i][14]
        tmp["startup"             ] = startup1
        tmp["piecewise_production"] = piecewise_production1
        gen["G_"+str(n)           ] = tmp
        tmp = {}
        result["thermal_generators"] = gen
        n = n + 1

    # f = open("{}/output.json".format("/content/"), "w")
    ##Genera archivo json
    sfile="{}/mk_"+str(nfile).zfill(3)+".json"
    print(sfile)
    f = open(sfile.format("/content/"), "w")
    f.write(str(result).replace("\'","\""))
    f.close()
    nfile = nfile + 1
# Out:
# 455 11
# 455 18
# 130 6
# 130 3
# 162 7
# 80 8
# 85 2
# 55 5
# capacidad 16584
# {}/mk_071.json
# 455 11
# 455 18
# 130 6
# 130 3
# 162 7
# 80 8
# 85 2
# 55 5
# capacidad 16584
# {}/mk_072.json
# 455 16
# 455 17
# 130 5
# 130 3
# 162 5
# 80 6
# 85 7
# 55 3
# capacidad 18105
# {}/mk_073.json
# 455 13
# 455 20
# 130 4
# 130 9
# 162 4
# 80 6
# 85 2
# 55 6
# capacidad 18333
# {}/mk_074.json
# 455 17
# 455 16
# 130 8
# 130 8
# 162 0
# 80 6
# 85 6
# 55 5
# capacidad 18360
# {}/mk_075.json
# 455 14
# 455 21
# 130 9
# 130 5
# 162 8
# 80 6
# 85 3
# 55 4
# capacidad 19996
# {}/mk_076.json
# 455 25
# 455 18
# 130 2
# 130 4
# 162 7
# 80 5
# 85 2
# 55 8
# capacidad 22489
# {}/mk_077.json
# 455 16
# 455 25
# 130 5
# 130 9
# 162 3
# 80 3
# 85 8
# 55 6
# capacidad 22211
# {}/mk_078.json
# 455 21
# 455 21
# 130 4
# 130 3
# 162 8
# 80 10
# 85 4
# 55 5
# capacidad 22731
# {}/mk_079.json
# 455 17
# 455 24
# 130 8
# 130 9
# 162 8
# 80 1
# 85 8
# 55 5
# capacidad 23196
# {}/mk_080.json
# 455 22
# 455 21
# ...
